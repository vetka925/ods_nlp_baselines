# %%
import pandas as pd
from common import DataProcessor, AutoClassifier
from utils import balance_binary_data

# %%
pd.read_csv('./data/train_b.csv')
# Out:
#       Unnamed: 0  Unnamed: 0.1  \
# 0              0           860
# 1              1          7738
# 2              2          2908
# 3              3          5933
# 4              4          1225
# ...          ...           ...
# 5967        5967          3249
# 5968        5968          5415
# 5969        5969          7781
# 5970        5970          9626
# 5971        5971          8162
#
#                                                    text  label1  \
# 0     Zum sich ausschweigen, aber , die einzige in d...       0
# 1      Ist er noch nicht weg? Er will DE doch mit sä...       1
# 2      Unter den US Schauspielern grassiert der link...       1
# 3      FY Kriechen tun nur die schäbigen Bastarde au...       1
# 4                 Auf die Bewährung schei.......ss ich!       1
# ...                                                 ...     ...
# 5967  In dem Schwarz Grün regierden Hessen werden je...       1
# 5968   |LBR| Und die sind noch hier? Abschieben nach...       0
# ...

# %%
regex = [r'(@|#)(\w+)', r'[(RT_:)|(RT:)]']
data = DataProcessor(data='./data/bert_train.csv', test='./data/bert_test.csv', class_column_name='identity_hate')
data.load_data()
data.prepare(regex)
# Out:
# ###### DATA INFO ######
#
# ### TEXT LENGTH ###
#
# count    12061.000000
# mean       119.946273
# std         89.774441
# min          1.000000
# 25%         66.000000
# 50%        107.000000
# 75%        150.000000
# max       3681.000000
# Name: text, dtype: float64
#
# #################
#
#
# WARNING: OUTLIED TEXT LENGTH VALUES
# TRY TO USE remove_outliers() METHOD
#
#
# #################
#
# Num classes: 2
#
# Class 0: 1
#
# Class 1: 0
#
#
# #################
#
#
# ### DATA HEAD ###
#
#                                                 text  identity_hate
# 0   klar denke ich anders als sie, ihr seit braun...              1
# 1  flüchtlinge begrabschen kinder in essener frei...              0
# 2  wir mä was wir uns so alles rausnehmen! wenn e...              0
# 3   ich weiß, es ging aber um kugelschreiber mit ...              0
# 4  deutschlands zukunft wird am hindukusch entsch...              1
# 5   ... und vor allem örtlich zuständiger mdb. un...              0
# ...

# %%
from sklearn.metrics import f1_score, recall_score, precision_score
from functools import partial
score_funcs = {'f1': f1_score}
auto = AutoClassifier(data)

# %%
auto.params_prepare()
reports = auto.get_report(score_funcs)
# Out:
# /Users/vetka925/Projects/auto_classification/venv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/vetka925/Projects/auto_classification/venv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
reports.sort_values('f1', ascending=False).head(1)
# Out:
#              vectorizer                                    model  \
# 434  supervised_stacked  LinearSVC(C=1, loss='hinge', tol=1e-05)
#
#                                       params  1_precision  1_recall  \
# 434  {'C': 1, 'loss': 'hinge', 'tol': 1e-05}     0.608108  0.422535
#
#      0_precision  0_recall        f1
# 434     0.896899  0.948582  0.498615

# %%
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd

count_ngram = CountVectorizer(
            analyzer="char", ngram_range=(4, 4), max_features=30000, max_df=0.7
        )
count_ngram.fit(pd.concat([data.X_train, data.X_test], ignore_index=True))
# Out:
# CountVectorizer(analyzer='char', max_df=0.7, max_features=30000,
#                 ngram_range=(4, 4))

# %%
from textvec.vectorizers import TfIcfVectorizer
vec = TfIcfVectorizer()
vec.fit(count_ngram.transform(data.X_test), data.y_test)

# %%
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()
l = enc.fit_transform(data.y_test)

# %%
import numpy as np
np.bincount(l, len(set(l)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-78f0786bf1e4> in <module>
#       1 import numpy as np
# ----> 2 np.bincount(l, len(set(l)))
#
# <__array_function__ internals> in bincount(*args, **kwargs)
#
# ValueError: object of too small depth for desired array

# %%
auto.vectorizers['supervised_ngram_level'].transform(data.te)

# %%
n_samples, n_features = X.shape
samples = []
self.number_of_classes = len(np.unique(y))
for val in range(self.number_of_classes):
    class_mask = sp.spdiags(y == val, 0, n_samples, n_samples)
    samples.append(np.bincount(
        (class_mask * X).indices, minlength=n_features))
samples = np.array(samples)
self.corpus_occurence = np.sum(samples != 0, axis=0)
self.k = np.log2(1 + (self.number_of_classes / self.corpus_occurence))
self._n_features = n_features
# Out:
# 4

# %%
reports.sort_values('f1', ascending=False)
# Out:
#               vectorizer                                              model  \
# 263   supervised_stacked  LogisticRegression(C=100, solver='liblinear', ...
# 262   supervised_stacked      LogisticRegression(C=100, solver='liblinear')
# 266   supervised_stacked  LogisticRegression(C=100, solver='sag', tol=1e...
# 269   supervised_stacked               LogisticRegression(C=100, tol=1e-05)
# 268   supervised_stacked                          LogisticRegression(C=100)
# ...                  ...                                                ...
# 1174   tfidf_ngram_level                                  LinearSVC(C=0.01)
# 1175   tfidf_ngram_level                       LinearSVC(C=0.01, tol=1e-05)
# 1176   tfidf_ngram_level          LinearSVC(C=0.1, loss='hinge', tol=0.001)
# 1177   tfidf_ngram_level                     LinearSVC(C=0.1, loss='hinge')
# 900    tfidf_ngram_level  LogisticRegression(C=0.01, solver='liblinear',...
#
# ...

# %%
reports.astype('str').to_csv('reports.csv')

# %%
vec = auto.vectorizers[reports.iloc[434].vectorizer]
model = reports.model.iloc[434]

# %%
from sklearn.metrics import classification_report
fs = vec.transform(data.X_test)
preds = model.predict(fs)
print(classification_report(data.y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.95      0.92      1128
#            1       0.61      0.42      0.50       213
#
#     accuracy                           0.87      1341
#    macro avg       0.75      0.69      0.71      1341
# weighted avg       0.85      0.87      0.85      1341
